# %% [markdown]
# # Mohammed Salman Inamdar

# %% [markdown]
# # Exploratory Data Analysis
#
# - Task 3
#
# - Perform EDA on SampleSuperstore
#
# - As a business manager, try to find out the weak areas where you can work to make more profit.

# %%
#importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## LOADING THE DATASET

# %%
file_name = "SampleSuperstore.csv"
df = pd.read_csv(file_name)

# %% [markdown]
# ## Print Last five row

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# ## CHECK THE MISSING VALUE

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ## Finding Total number of null values in a dataset

# %%
print("total number of null values = ",df.isnull().sum().sum())
# Out:
# total number of null values =  0

# %% [markdown]
# ## Full summary of the dataframe

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB
# None

# %% [markdown]
# ## Statistical details of the dataset

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Shape of dataset

# %%
df.shape
# Out:
# (9994, 13)

# %% [markdown]
# ## Find the dtypes in the Dataset

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## Finding all the column names inside the dataset

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ## Check the dataset for duplicate ,drop if any

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ## Number of distinct observations

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# # Correlation of dataset

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# # Covariance of dataset

# %%
df.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount  \
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228
# Quantity     9.104159e+02     278.459923    4.951113    0.003961
# Discount     3.868704e+02      -3.627228    0.003961    0.042622
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173
#
#                     Profit
# Postal Code -225045.849445
# Sales         69944.096586
# Quantity         34.534769
# Discount        -10.615173
# Profit        54877.798055

# %% [markdown]
# # Deleting the Variable
#
# - Postal Code

# %%
col=['Postal Code']
df1=df.drop(columns=col,axis=1)

# %% [markdown]
# ## HEATMAP OF DATASET

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(df.corr(),cmap="YlGnBu", annot= True)
plt.show()

# %%
fig,axes = plt.subplots(1,1,figsize=(9,6))
sns.heatmap(df.cov(), annot= True)
plt.show()

# %% [markdown]
# # Proper Visualization of the Data set

# %%
plt.figure(figsize=(16,8))
plt.bar('Sub-Category','Category', data=df,color='b')
plt.show()

# %% [markdown]
# ## Quantites ordered by state

# %%
plt.figure(figsize = (20, 9))
sns.countplot(x = df['State'], palette = 'winter_r', order = (df['State'].value_counts().head(50)).index)
plt.xticks(rotation = 50, ha = 'right', fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlabel('State', fontsize = 15)
plt.ylabel('Quantities ordered', fontsize = 15)
# Out:
# Text(0, 0.5, 'Quantities ordered')

# %% [markdown]
# ## Sub-category Wise Distribution In Different Regions

# %%
plt.figure(figsize = (30, 12))
sns.countplot(x = 'Sub-Category', hue = 'Region', data = df,palette='twilight_r')
plt.xticks(rotation = 45, fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Sub-Categories', fontsize = 25)
plt.ylabel('', fontsize = 20)
plt.legend(loc = 5, fontsize = 20)

# %% [markdown]
# ## Visualizing sub-category wise distribution of sales

# %%
# visualizing sub-category wise distribution of sales
plt.figure(figsize=(12,10))
df['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %% [markdown]
# ## Customer's per segment

# %%
#What is the distribution of our customer segment
fig = plt.figure(figsize=(12,8))
ax = fig.add_subplot(111)
p = sns.countplot(x="Segment", data=df, ax=ax)
ax.set_title("Customer Distribution by Segment")
ax.set_xticklabels(p.get_xticklabels(), rotation=90)
for p in ax.patches:
    ax.annotate('{:.0f}'.format(p.get_height()), (p.get_x()+0.15, p.get_height()+1))
plt.tight_layout()
plt.show()

# %%
sns.countplot(x=df['Segment'])

# %%
sns.countplot(x=df['Region'])

# %% [markdown]
# ## Categories classified according to the region.

# %%
plt.figure(figsize = (30, 12))
sns.countplot(x = 'Category', hue = 'Region', data = df, palette = 'icefire')
plt.xticks(rotation = 45, fontsize = 20)
plt.yticks(fontsize = 20)
plt.xlabel('Categories', fontsize = 25)
plt.ylabel('', fontsize = 20)
plt.legend(loc = 5, fontsize = 20)

# %% [markdown]
# ## Sales by Region

# %%
sales_by_region = df.groupby('Region').size()
plt.figure(figsize=(10,6))
plot_by_region = sales_by_region.plot(title='Sales by Region',xticks=(1,2,3,4),lw=3,c='purple')
plot_by_region.set_xlabel('Region',size=12)
plot_by_region.set_ylabel('Sales',size=12)
# Out:
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Observation:
#
# - South Region has worst performance
#
# - East & West have beter performance

# %% [markdown]
# ## Sales by Ship Mode

# %%
sales_by_shipmode = df.groupby('Ship Mode').size()
print(sales_by_shipmode)
plt.figure(figsize=(10,6))
sales_by_shipmode = sales_by_shipmode.plot(title='Sales by Ship Mode',lw=3,c='r')
sales_by_shipmode.set_xlabel('Ship Mode',size=12)
sales_by_shipmode.set_ylabel('Sales',size=12)
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# dtype: int64
# Text(0, 0.5, 'Sales')

# %% [markdown]
# ## Observations:
#
# - Standard Class Shipments is choosen by Majority of customers
#
# - Many customers opt for Second Class Shipment
#
# - Customers opting for Same Day Shipment a very less

# %% [markdown]
# ## Distribution of profit sales per sub-category

# %%
plt.figure(figsize=(10,6))
df.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar()
plt.title('Total Profit and Sales per Sub-Category')
# plt.legend('Profit')
# plt.legend('Sales')
plt.show()
# Out:
# C:\Users\SALAMAN\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# ## Let's see relation b/w discount and profit

# %%
#df1 is the data set which does not contain 'postal code'

plt.figure(figsize = (12,6))
ax=sns.lineplot('Discount', 'Profit', data = df, color = '#ad26eb', label= 'Discount')
ax.set_xlabel('Discount',size=14)
ax.set_ylabel('Profit',size=14)
plt.legend()

# %%
ax=sns.lineplot('Discount', 'Sales', data = df,  label= 'Discount')

# %%
df1.hist(bins=50 ,figsize=(20,15),color='#9226eb')
plt.show()

# %%
# Pairplot between every data

figsize=(15,10)
sns.pairplot(df1,hue='Sub-Category')

# %%
# Pairplot between every data

figsize=(15,10)
sns.pairplot(df1)

# %%
#grouping the data we want
grouped=pd.DataFrame(df.groupby(['Ship Mode','Segment','Category','Sub-Category','State','Region'])['Quantity','Discount','Sales','Profit'].sum().reset_index())
grouped
# Out:
# C:\Users\SALAMAN\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#            Ship Mode      Segment    Category Sub-Category       State  \
# 0        First Class     Consumer   Furniture    Bookcases     Arizona
# 1        First Class     Consumer   Furniture    Bookcases  California
# 2        First Class     Consumer   Furniture    Bookcases    Colorado
# 3        First Class     Consumer   Furniture    Bookcases     Florida
# 4        First Class     Consumer   Furniture    Bookcases     Georgia
# ...              ...          ...         ...          ...         ...
# 2978  Standard Class  Home Office  Technology       Phones       Texas
# 2979  Standard Class  Home Office  Technology       Phones     Vermont
# 2980  Standard Class  Home Office  Technology       Phones    Virginia
# ...

# %%
figsize=(15,10)
sns.pairplot(grouped,hue='Sub-Category')

# %% [markdown]
# ## Profit Per Sub-category

# %%
plt.figure(figsize=(17,8))
sns.barplot(df['Sub-Category'], df['Profit'])

# %% [markdown]
# # Distribution Plot

# %%
plt.rcParams['figure.figsize'] = (15, 8)
sns.distplot(df['Sales'], color = '#ed0e67')
plt.title('The Distribution of Sales', fontsize = 30)
plt.xlabel('Range of Sales', fontsize = 15)
plt.ylabel('No. of Sales count', fontsize = 15)
plt.show()

# %% [markdown]
# # Refrences
#
# - seaborn:  https://seaborn.pydata.org/
#
# - matplotlib https://matplotlib.org/contents.html

# %% [markdown]
# ###  THANK YOU :)
